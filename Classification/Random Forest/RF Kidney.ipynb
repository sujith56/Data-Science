# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('kidney.csv')

# %%
data
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4      4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5      5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6      6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# 11    11  63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present
# ...

# %%
data.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
M = data['age'].mean()
M
# Out:
# 51.48337595907928

# %%
data['age'].fillna(value=M,inplace=True)

# %%
M1 = data['bp'].mean()
M1
# Out:
# 76.46907216494846

# %%
data['bp'].fillna(value=M1,inplace=True)

# %%
M2 = data['sg'].mean()
M2
# Out:
# 1.0174079320113256

# %%
data['sg'].fillna(value=M2,inplace=True)

# %%
M3 = data['al'].mean()
M3
# Out:
# 1.0169491525423728

# %%
data['al'].fillna(value=M3,inplace=True)

# %%
M4 = data['su'].mean()
M4
# Out:
# 0.45014245014245013

# %%
data['su'].fillna(value=M4,inplace=True)

# %%
data['rbc'].fillna(value='FILL_VALUE',inplace=True)

# %%
data['pc'].fillna(value='FILL_VALUE',inplace=True)
data['pcc'].fillna(value='FILL_VALUE',inplace=True)
data['ba'].fillna(value='FILL_VALUE',inplace=True)
data['htn'].fillna(value='FILL_VALUE',inplace=True)
data['dm'].fillna(value='FILL_VALUE',inplace=True)
data['cad'].fillna(value='FILL_VALUE',inplace=True)
data['appet'].fillna(value='FILL_VALUE',inplace=True)
data['pe'].fillna(value='FILL_VALUE',inplace=True)
data['ane'].fillna(value='FILL_VALUE',inplace=True)
data['classification'].fillna(value='FILL_VALUE',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
data.rbc = enc.fit_transform(data.rbc)
data.pc = enc.fit_transform(data.pc)
data.pcc = enc.fit_transform(data.pcc)
data.ba = enc.fit_transform(data.ba)
data.htn = enc.fit_transform(data.htn)
data.dm = enc.fit_transform(data.dm)
data.cad = enc.fit_transform(data.cad)
data.appet = enc.fit_transform(data.appet)
data.pe = enc.fit_transform(data.pe)
data.ane = enc.fit_transform(data.ane)
data.classification = enc.fit_transform(data.classification)

# %%
M5 = data['rbc'].mean()
M5
# Out:
# 1.1225

# %%
data['rbc'].fillna(value=M5,inplace=True)

# %%
M6 = data['pc'].mean()
M6
# Out:
# 1.485

# %%
data['pc'].fillna(value=M6,inplace=True)

# %%
M7 = data['pcc'].mean()
M7
# Out:
# 1.095

# %%
data['pcc'].fillna(value=M7,inplace=True)

# %%
M8 = data['ba'].mean()
M8
# Out:
# 1.045

# %%
data['ba'].fillna(value=M8,inplace=True)

# %%
M9 = data['bgr'].mean()
M9
# Out:
# 148.0365168539326

# %%
data['bgr'].fillna(value=M9,inplace=True)

# %%
M10 = data['bu'].mean()
M10
# Out:
# 57.425721784776904

# %%
data['bu'].fillna(value=M10,inplace=True)

# %%
M11 = data['sc'].mean()
M11
# Out:
# 3.0724543080939934

# %%
data['sc'].fillna(value=M11,inplace=True)

# %%
M12 = data['sod'].mean()
M12
# Out:
# 137.52875399361022

# %%
data['sod'].fillna(value=M12,inplace=True)

# %%
M13 = data['pot'].mean()
M13
# Out:
# 4.627243589743592

# %%
data['pot'].fillna(value=M13,inplace=True)

# %%
M14 = data['hemo'].mean()
M14
# Out:
# 12.526436781609195

# %%
data['hemo'].fillna(value=M14,inplace=True)

# %%
M15 = data['htn'].mean()
M15
# Out:
# 1.3625

# %%
data['htn'].fillna(value=True,inplace=True)

# %%
M16 = data['dm'].mean()
M16
# Out:
# 4.28

# %%
data['dm'].fillna(value=M16,inplace=True)

# %%
M17 = data['cad'].mean()
M17
# Out:
# 2.07

# %%
data['cad'].fillna(value=M17,inplace=True)

# %%
M18 = data['appet'].mean()
M18
# Out:
# 1.2025

# %%
data['appet'].fillna(value=M18,inplace=True)

# %%
M19 = data['pe'].mean()
M19
# Out:
# 1.1875

# %%
data['pe'].fillna(value=M19,inplace=True)

# %%
M20 = data['ane'].mean()
M20
# Out:
# 1.1475

# %%
data['ane'].fillna(value=M20,inplace=True)

# %%
data.isnull().sum()
# Out:
# id                  0
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc                 0
# pc                  0
# pcc                 0
# ba                  0
# bgr                 0
# bu                  0
# sc                  0
# sod                 0
# pot                 0
# hemo                0
# pcv                70
# wc                105
# rc                130
# htn                 0
# dm                  0
# cad                 0
# appet               0
# pe                  0
# ane                 0
# classification      0
# dtype: int64

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su  rbc  pc  pcc  ba  ...  pcv    wc   rc  \
# 0   0  48.0  80.0  1.020  1.0  0.0    0   2    1   1  ...   44  7800  5.2
# 1   1   7.0  50.0  1.020  4.0  0.0    0   2    1   1  ...   38  6000  NaN
# 2   2  62.0  80.0  1.010  2.0  3.0    2   2    1   1  ...   31  7500  NaN
# 3   3  48.0  70.0  1.005  4.0  0.0    2   1    2   1  ...   32  6700  3.9
# 4   4  51.0  80.0  1.010  2.0  0.0    2   2    1   1  ...   35  7300  4.6
#
#    htn  dm  cad appet pe ane  classification
# 0    2   5    2     1  1   1               0
# 1    1   4    2     1  1   1               0
# 2    1   5    2     2  1   2               0
# 3    2   4    2     2  2   2               0
# 4    1   4    2     1  1   1               0
#
# [5 rows x 26 columns]

# %%
data['pcv'].fillna(value='FILL_VALUE',inplace=True)
data['wc'].fillna(value='FILL_VALUE',inplace=True)
data['rc'].fillna(value='FILL_VALUE',inplace=True)

# %%
data.pcv = enc.fit_transform(data.pcv)

# %%
data.wc = enc.fit_transform(data.wc)

# %%
data.rc = enc.fit_transform(data.rc)

# %%
M21 = data['pcv'].mean()

# %%
M21
# Out:
# 29.8525

# %%
data['pcv'].fillna(value=M21,inplace=True)

# %%
M22 = data['wc'].mean()
M22
# Out:
# 64.43

# %%
data['wc'].fillna(value=M22,inplace=True)

# %%
M23 = data['rc'].mean()
M23
# Out:
# 34.8375

# %%
data['rc'].fillna(value=M23,inplace=True)

# %%
data.isnull().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su  rbc  pc  pcc  ba  ...  pcv  wc  rc  htn  \
# 0   0  48.0  80.0  1.020  1.0  0.0    0   2    1   1  ...   32  72  34    2
# 1   1   7.0  50.0  1.020  4.0  0.0    0   2    1   1  ...   26  56  49    1
# 2   2  62.0  80.0  1.010  2.0  3.0    2   2    1   1  ...   19  70  49    1
# 3   3  48.0  70.0  1.005  4.0  0.0    2   1    2   1  ...   20  62  19    2
# 4   4  51.0  80.0  1.010  2.0  0.0    2   2    1   1  ...   23  68  27    1
#
#    dm  cad  appet  pe  ane  classification
# 0   5    2      1   1    1               0
# 1   4    2      1   1    1               0
# 2   5    2      2   1    2               0
# 3   4    2      2   2    2               0
# 4   4    2      1   1    1               0
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (400, 26)

# %%
y = data.classification
X = data.iloc[:,:26]

# %%
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\home\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=20)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predict = model.predict(X_test)

# %%
y_test
# Out:
# 10     0
# 382    2
# 374    2
# 196    0
# 47     0
# 237    0
# 175    0
# 347    2
# 115    0
# 308    2
# 235    0
# 13     0
# 211    0
# 205    0
# 102    0
# 192    0
# 34     0
# 17     0
# 56     0
# 247    0
# 9      0
# 81     0
# 166    0
# 92     0
# 359    2
# 7      0
# 338    2
# 98     0
# 383    2
# 352    2
#       ..
# 14     0
# 361    2
# 258    2
# 157    0
# 322    2
# 369    2
# 257    2
# 61     0
# 367    2
# 346    2
# 356    2
# 358    2
# 104    0
# 221    0
# 392    2
# 121    0
# 208    0
# 256    2
# 250    2
# 267    2
# 226    0
# 303    2
# 241    0
# 297    2
# 165    0
# 336    2
# 398    2
# 45     0
# 373    2
# 28     0
# Name: classification, Length: 80, dtype: int32

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,predict)
# Out:
# 1.0

# %%
confusion_matrix(y_test,predict)
# Out:
# array([[46,  0],
#        [ 0, 34]], dtype=int64)

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        46
#            2       1.00      1.00      1.00        34
#
#    micro avg       1.00      1.00      1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80
