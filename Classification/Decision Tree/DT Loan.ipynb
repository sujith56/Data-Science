# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('hmeq.csv')

# %%
data
# Out:
#       BAD   LOAN   MORTDUE     VALUE   REASON      JOB   YOJ  DEROG  DELINQ  \
# 0       1   1100   25860.0   39025.0  HomeImp    Other  10.5    0.0     0.0
# 1       1   1300   70053.0   68400.0  HomeImp    Other   7.0    0.0     2.0
# 2       1   1500   13500.0   16700.0  HomeImp    Other   4.0    0.0     0.0
# 3       1   1500       NaN       NaN      NaN      NaN   NaN    NaN     NaN
# 4       0   1700   97800.0  112000.0  HomeImp   Office   3.0    0.0     0.0
# 5       1   1700   30548.0   40320.0  HomeImp    Other   9.0    0.0     0.0
# 6       1   1800   48649.0   57037.0  HomeImp    Other   5.0    3.0     2.0
# 7       1   1800   28502.0   43034.0  HomeImp    Other  11.0    0.0     0.0
# 8       1   2000   32700.0   46740.0  HomeImp    Other   3.0    0.0     2.0
# 9       1   2000       NaN   62250.0  HomeImp    Sales  16.0    0.0     0.0
# 10      1   2000   22608.0       NaN      NaN      NaN  18.0    NaN     NaN
# ...

# %%
data.shape
# Out:
# (5960, 13)

# %%
data.isnull().sum()
# Out:
# BAD           0
# LOAN          0
# MORTDUE     518
# VALUE       112
# REASON      252
# JOB         279
# YOJ         515
# DEROG       708
# DELINQ      580
# CLAGE       308
# NINQ        510
# CLNO        222
# DEBTINC    1267
# dtype: int64

# %%
M = data['MORTDUE'].mean()
M
# Out:
# 73760.81719955898

# %%
data['MORTDUE'].fillna(value=M,inplace=True)

# %%
M1 = data['VALUE'].mean()
M1
# Out:
# 101776.04874145007

# %%
data['VALUE'].fillna(value=M1,inplace=True)

# %%
M2 = data['YOJ'].mean()
M2
# Out:
# 8.922268135904508

# %%
data['YOJ'].fillna(value=M2,inplace=True)

# %%
M3 = data['DEROG'].mean()
M3
# Out:
# 159.0491610738255

# %%
data['DEROG'].fillna(value=M3,inplace=True)

# %%
M4 = data['DELINQ'].mean()
M4
# Out:
# 0.4494423791821561

# %%
data['DELINQ'].fillna(value=M4,inplace=True)

# %%
M5 = data['CLAGE'].mean()
M5
# Out:
# 179.76627518656667

# %%
data['CLAGE'].fillna(value=M5,inplace=True)

# %%
M6 = data['NINQ'].mean()
M6
# Out:
# 1.1860550458715597

# %%
data['NINQ'].fillna(value=M6,inplace=True)

# %%
M7 = data['CLNO'].mean()
M7
# Out:
# 21.29609620076682

# %%
data['CLNO'].fillna(value=M7,inplace=True)

# %%
M8 = data['DEBTINC'].mean()
M8
# Out:
# 33.779915348721225

# %%
data['DEBTINC'].fillna(value=M8,inplace=True)

# %%
data.isnull().sum()
# Out:
# BAD          0
# LOAN         0
# MORTDUE      0
# VALUE        0
# REASON     252
# JOB        279
# YOJ          0
# DEROG        0
# DELINQ       0
# CLAGE        0
# NINQ         0
# CLNO         0
# DEBTINC      0
# dtype: int64

# %%
data['REASON'].fillna(value='FILL_VALUE',inplace=True)

# %%
data['JOB'].fillna(value='FILL_VALUE',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
data.REASON = enc.fit_transform(data.REASON)

# %%
data.JOB = enc.fit_transform(data.JOB)

# %%
data.head()
# Out:
#    BAD  LOAN     MORTDUE   VALUE  REASON  JOB        YOJ   DEROG    DELINQ  \
# 0    1  1100  25860.0000   39025       2    3  10.500000     0.0  0.000000
# 1    1  1300  70053.0000   68400       2    3   7.000000     0.0  2.000000
# 2    1  1500  13500.0000   16700       2    3   4.000000     0.0  0.000000
# 3    1  1500  73760.8172    True       1    0   8.922268  1337.0  0.449442
# 4    0  1700  97800.0000  112000       2    2   3.000000     0.0  0.000000
#
#         CLAGE      NINQ       CLNO    DEBTINC
# 0   94.366667  1.000000   9.000000  33.779915
# 1  121.833333  0.000000  14.000000  33.779915
# 2  149.466667  1.000000  10.000000  33.779915
# 3  179.766275  1.186055  21.296096  33.779915
# 4   93.333333  0.000000  14.000000  33.779915

# %%
M9 = data['REASON'].mean()
M9
# Out:
# 0.6395973154362417

# %%
data['REASON'].fillna(value=M9,inplace=True)

# %%
M10 = data['JOB'].mean()
M10
# Out:
# 2.790939597315436

# %%
data['JOB'].fillna(value=M10,inplace=True)

# %%
data
# Out:
#       BAD   LOAN      MORTDUE   VALUE  REASON  JOB        YOJ   DEROG  \
# 0       1   1100   25860.0000   39025       2    3  10.500000     0.0
# 1       1   1300   70053.0000   68400       2    3   7.000000     0.0
# 2       1   1500   13500.0000   16700       2    3   4.000000     0.0
# 3       1   1500   73760.8172    True       1    0   8.922268  1337.0
# 4       0   1700   97800.0000  112000       2    2   3.000000     0.0
# 5       1   1700   30548.0000   40320       2    3   9.000000     0.0
# 6       1   1800   48649.0000   57037       2    3   5.000000     3.0
# 7       1   1800   28502.0000   43034       2    3  11.000000     0.0
# 8       1   2000   32700.0000   46740       2    3   3.000000     0.0
# 9       1   2000   73760.8172   62250       2    5  16.000000     0.0
# 10      1   2000   22608.0000    True       1    0  18.000000  1337.0
# 11      1   2000   20627.0000   29800       2    2  11.000000     0.0
# ...

# %%
data.isnull().sum()
# Out:
# BAD        0
# LOAN       0
# MORTDUE    0
# VALUE      0
# REASON     0
# JOB        0
# YOJ        0
# DEROG      0
# DELINQ     0
# CLAGE      0
# NINQ       0
# CLNO       0
# DEBTINC    0
# dtype: int64

# %%
data.shape
# Out:
# (5960, 13)

# %%
data.head()
# Out:
#    BAD  LOAN     MORTDUE   VALUE  REASON  JOB        YOJ   DEROG    DELINQ  \
# 0    1  1100  25860.0000   39025       2    3  10.500000     0.0  0.000000
# 1    1  1300  70053.0000   68400       2    3   7.000000     0.0  2.000000
# 2    1  1500  13500.0000   16700       2    3   4.000000     0.0  0.000000
# 3    1  1500  73760.8172    True       1    0   8.922268  1337.0  0.449442
# 4    0  1700  97800.0000  112000       2    2   3.000000     0.0  0.000000
#
#         CLAGE      NINQ       CLNO    DEBTINC
# 0   94.366667  1.000000   9.000000  33.779915
# 1  121.833333  0.000000  14.000000  33.779915
# 2  149.466667  1.000000  10.000000  33.779915
# 3  179.766275  1.186055  21.296096  33.779915
# 4   93.333333  0.000000  14.000000  33.779915

# %%
y = data.BAD
X = data.iloc[:,1:]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=80)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
X_train.head()
# Out:
#        LOAN  MORTDUE  VALUE  REASON  JOB   YOJ   DEROG    DELINQ       CLAGE  \
# 2270  13900  64356.0  88028       0    2  13.0     0.0  0.000000  111.809975
# 2073  13100  64897.0  81598       0    5   7.0     0.0  0.000000  130.648468
# 2409  14500  67956.0  80318       0    3   1.0     0.0  0.000000  233.397273
# 5306  29500  48590.0  81354       0    2   0.0     0.0  0.000000  157.026326
# 2426  14600  59658.0  80384       0    0   8.0  1337.0  0.449442  179.766275
#
#           NINQ       CLNO    DEBTINC
# 2270  0.000000  24.000000  39.008508
# 2073  0.000000  34.000000  26.500105
# 2409  2.000000  26.000000  31.316415
# 5306  3.000000  18.000000  40.170618
# 2426  1.186055  21.296096  25.192869

# %%
y_train.head()
# Out:
# 2270    0
# 2073    0
# 2409    0
# 5306    0
# 2426    0
# Name: BAD, dtype: int64

# %%
predict = model.predict(X_test)

# %%
y_test
# Out:
# 2721    0
# 2636    0
# 3086    1
# 2199    0
# 4164    0
# 3107    0
# 4173    0
# 5350    0
# 1983    0
# 1949    0
# 5803    1
# 943     0
# 2410    1
# 3078    0
# 5158    0
# 4262    0
# 2014    0
# 4659    0
# 1046    0
# 208     0
# 2202    1
# 4428    1
# 5041    0
# 3941    1
# 3701    0
# 3174    0
# 5543    0
# 2260    1
# 112     0
# 2495    0
#        ..
# 5745    0
# 3422    1
# 4356    0
# 5423    0
# 1367    0
# 476     0
# 4214    0
# 678     1
# 5446    1
# 784     0
# 4508    0
# 5723    1
# 5732    0
# 2858    0
# 514     0
# 2686    0
# 2119    0
# 1947    0
# 4910    0
# 5806    0
# 5217    0
# 2149    0
# 1639    0
# 4220    0
# 4749    1
# 4457    1
# 3378    0
# 4232    0
# 5708    1
# 3713    1
# Name: BAD, Length: 1490, dtype: int64

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,predict)
# Out:
# 0.8751677852348994

# %%
confusion_matrix(y_test,predict)
# Out:
# array([[1090,   95],
#        [  91,  214]], dtype=int64)

# %%
print(classification_report(y_test,predi))
